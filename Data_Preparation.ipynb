# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !mkdir "/content/ADHBASE"
# !mkdir "/content/MAHDBASE"

# %%
# !cd ADHBASE/

# %%
# !cp "/content/gdrive/My Drive/Urdu_mnist/AHDBase_TrainingSet.rar" "/content/ADHBASE"
# !cp "/content/gdrive/My Drive/Urdu_mnist/AHDBase_TestingSet.rar" "/content/ADHBASE"

# !cp "/content/gdrive/My Drive/Urdu_mnist/MAHDBase_TrainingSet.rar" "/content/MAHDBASE"
# !cp "/content/gdrive/My Drive/Urdu_mnist/MAHDBase_TestingSet.rar" "/content/MAHDBASE"

# %%
# !mkdir ADHBASE_DATA
# !mkdir MAHDBASE_DATA

# %%
# !unrar x "/content/ADHBASE/AHDBase_TestingSet.rar"  "/content/ADHBASE_DATA"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !unrar x "/content/ADHBASE/AHDBase_TrainingSet.rar"  "/content/ADHBASE_DATA"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !unrar x "/content/MAHDBASE/MAHDBase_TrainingSet.rar"  "/content/MAHDBASE_DATA"
# !unrar x "/content/MAHDBASE/MAHDBase_TestingSet.rar"  "/content/MAHDBASE_DATA"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
import os 
path ="/content/ADHBASE_DATA/AHDBase_TrainingSet/"
count=0
for i in os.listdir(path):
  for j in os.listdir("/content/ADHBASE_DATA/AHDBase_TrainingSet/"+i):
    count=count+1
print("Training dataset size for ADHBASE",count)


path ="/content/ADHBASE_DATA/AHDBase_TestingSet/"
count=0
for i in os.listdir(path):
  for j in os.listdir("/content/ADHBASE_DATA/AHDBase_TestingSet/"+i):
    count=count+1
print("Testing dataset size for ADHBASE",count)
# Out:
# Training dataset size for ADHBASE 60012
# Testing dataset size for ADHBASE 10002

# %%
path ="/content/MAHDBASE_DATA/MAHDBase_TrainingSet"
count=0
for i in os.listdir(path):
  for j in os.listdir("/content/MAHDBASE_DATA/MAHDBase_TrainingSet/"+i):
    count=count+1
print("Training dataset size for MAHDBASE",count)


path ="/content/MAHDBASE_DATA/MAHDBase_TestingSet"
count=0
for i in os.listdir(path):
  for j in os.listdir("/content/MAHDBASE_DATA/MAHDBase_TestingSet/"+i):
    count=count+1
print("Testing dataset size for MAHDBASE",count)
# Out:
# Training dataset size for MAHDBASE 60001
# Testing dataset size for MAHDBASE 10001

# %%
s="/content/MAHDBASE_DATA/MAHDBase_TrainingSet/Part01/writer001_pass01_digit0.bmp"
a=s.split(".")
if "digit0" in a[0]:
  print("yes")
  f=a[0].split("/")[-1]
else:
  print("no")
# Out:
# yes

# %%
# Out:
# 'writer001_pass01_digit0'

# %%
# !mkdir "/content/dataset"

# %%
for i in range(0,10):
  os.mkdir("/content/dataset/digit_"+str(i))

# %%
import tqdm
import shutil

# %%
path="/content/MAHDBASE_DATA/MAHDBase_TrainingSet"
count=0
dig=["digit0","digit1","digit2","digit3","digit4","digit5","digit6","digit7","digit8","digit9"]
for i in os.listdir(path):
  for j in os.listdir(path+"/"+i):
    if "digit0" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_0")
    
    elif "digit1" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_1")
    elif "digit2" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_2")
    elif "digit3" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_3")
    elif "digit4" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_4")
    elif "digit5" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_5")
    elif "digit6" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_6")
    elif "digit7" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_7")
    elif "digit8" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_8")
    elif "digit9" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/dataset/digit_9")

# %%
#count=0
import random 
for i in os.listdir("/content/dataset/"):
  count=0
  print("Directory: ",i)
  for j in os.listdir("/content/dataset/"+i):
    count=count+1
  print(count)
  print("Printing Random file from the directory: ", random.choice(os.listdir("/content/dataset/"+i+"/")))
  print("---------------------------")
# Out:
# Directory:  digit_6
# 7000
# Printing Random file from the directory:  writer392_pass09_digit6.bmp
# ---------------------------
# Directory:  digit_3
# 7000
# Printing Random file from the directory:  writer093_pass10_digit3.bmp
# ---------------------------
# Directory:  digit_9
# 7000
# Printing Random file from the directory:  writer267_pass08_digit9.bmp
# ---------------------------
# Directory:  digit_7
# 7000
# Printing Random file from the directory:  writer300_pass03_digit7.bmp
# ---------------------------
# Directory:  digit_5
# 7000
# Printing Random file from the directory:  writer517_pass04_digit5.bmp
# ---------------------------
# Directory:  digit_2
# 7000
# Printing Random file from the directory:  writer052_pass10_digit2.bmp
# ---------------------------
# Directory:  digit_8
# 7000
# Printing Random file from the directory:  writer324_pass05_digit8.bmp
# ---------------------------
# Directory:  digit_0
# 7000
# ...

# %%
# !mkdir "/content/test_dataset"

# %%
for i in range(0,10):
  os.mkdir("/content/test_dataset/digit_"+str(i))

# %%
path="/content/MAHDBASE_DATA/MAHDBase_TestingSet"
count=0
dig=["digit0","digit1","digit2","digit3","digit4","digit5","digit6","digit7","digit8","digit9"]
for i in os.listdir(path):
  for j in os.listdir(path+"/"+i):
    if "digit0" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_0")
    
    elif "digit1" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_1")
    elif "digit2" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_2")
    elif "digit3" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_3")
    elif "digit4" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_4")
    elif "digit5" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_5")
    elif "digit6" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_6")
    elif "digit7" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_7")
    elif "digit8" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_8")
    elif "digit9" in j:
      shutil.copy(path+"/"+i+"/"+j,"/content/test_dataset/digit_9")

# %%
#count=0
import random 
for i in os.listdir("/content/test_dataset/"):
  count=0
  print("Directory: ",i)
  for j in os.listdir("/content/test_dataset/"+i):
    count=count+1
  print(count)
  print("Printing Random file from the directory: ", random.choice(os.listdir("/content/test_dataset/"+i+"/")))
  print("---------------------------")
# Out:
# Directory:  digit_6
# 1000
# Printing Random file from the directory:  writer602_pass06_digit6.bmp
# ---------------------------
# Directory:  digit_3
# 1000
# Printing Random file from the directory:  writer655_pass08_digit3.bmp
# ---------------------------
# Directory:  digit_9
# 1000
# Printing Random file from the directory:  writer680_pass01_digit9.bmp
# ---------------------------
# Directory:  digit_7
# 1000
# Printing Random file from the directory:  writer700_pass04_digit7.bmp
# ---------------------------
# Directory:  digit_5
# 1000
# Printing Random file from the directory:  writer693_pass05_digit5.bmp
# ---------------------------
# Directory:  digit_2
# 1000
# Printing Random file from the directory:  writer656_pass09_digit2.bmp
# ---------------------------
# Directory:  digit_8
# 1000
# Printing Random file from the directory:  writer672_pass02_digit8.bmp
# ---------------------------
# Directory:  digit_0
# 1000
# ...

# %%
# !zip -r final_dataset.zip "/content/dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/dataset/digit_1/writer044_pass05_digit1.bmp (deflated 42%)
#   adding: content/dataset/digit_1/writer255_pass09_digit1.bmp (deflated 42%)
#   adding: content/dataset/digit_1/writer142_pass02_digit1.bmp (deflated 41%)
#   adding: content/dataset/digit_1/writer567_pass08_digit1.bmp (deflated 42%)
#   adding: content/dataset/digit_1/writer296_pass10_digit1.bmp (deflated 42%)
#   adding: content/dataset/digit_1/writer115_pass04_digit1.bmp (deflated 42%)
#   adding: content/dataset/digit_1/writer337_pass04_digit1.bmp (deflated 46%)
#   adding: content/dataset/digit_1/writer097_pass04_digit1.bmp (deflated 42%)
#   adding: content/dataset/digit_1/writer522_pass06_digit1.bmp (deflated 40%)
#   adding: content/dataset/digit_1/writer362_pass04_digit1.bmp (deflated 42%)
#   adding: content/dataset/digit_1/writer199_pass01_digit1.bmp (deflated 43%)
# ...

# %%
# !zip -r test_dataset.zip "/content/test_dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/test_dataset/digit_2/writer659_pass04_digit2.bmp (deflated 39%)
#   adding: content/test_dataset/digit_2/writer609_pass08_digit2.bmp (deflated 39%)
#   adding: content/test_dataset/digit_2/writer644_pass01_digit2.bmp (deflated 36%)
#   adding: content/test_dataset/digit_2/writer611_pass04_digit2.bmp (deflated 40%)
#   adding: content/test_dataset/digit_2/writer646_pass05_digit2.bmp (deflated 39%)
#   adding: content/test_dataset/digit_2/writer662_pass10_digit2.bmp (deflated 38%)
#   adding: content/test_dataset/digit_2/writer629_pass03_digit2.bmp (deflated 38%)
#   adding: content/test_dataset/digit_2/writer649_pass01_digit2.bmp (deflated 37%)
#   adding: content/test_dataset/digit_2/writer692_pass08_digit2.bmp (deflated 38%)
#   adding: content/test_dataset/digit_2/writer617_pass10_digit2.bmp (deflated 37%)
#   adding: content/test_dataset/digit_2/writer677_pass04_digit2.bmp (deflated 37%)
# ...

# %%
import numpy as np 
import pandas as pd 
import sklearn

# %%
# !cp "/content/dataset.zip" "/content/gdrive/My Drive/Urdu_mnist"
# !cp "/content/test_dataset.zip" "/content/gdrive/My Drive/Urdu_mnist"

# %%
# !cp "/content/final_dataset.zip" "/content/gdrive/My Drive/Urdu_mnist"

# %%
# !rsync -a /content/test_dataset/ /content/dataset

# %%
path = "/content/dataset"
count=0
for i in os.listdir(path):
  for j in os.listdir(path+"/"+i):
    count=count+1

# %%
from PIL import Image
import numpy as np
import sys
import os
import csv

# %%
img_file=Image.open("/content/dataset/digit_0/writer001_pass01_digit0.bmp")

# %%
import matplotlib.pyplot as plt

# %%
img_file.show()

# %%
width, height = img_file.size
format = img_file.format
mode = img_file.mode

# Make image Greyscale
img_grey = img_file.convert('1')
img_grey.save('result.png')
img_grey.show()

# Save Greyscale values
value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
value = value.flatten()
value=[1 if x == 255 else x for x in value]
value.append(0)
with open("img_pixels.csv", 'a') as f:
    writer = csv.writer(f)
    writer.writerow(value)

# %%
path="/content/dataset/digit_0"

# %%
img_file=Image.open(path+"/"+j)

width, height = img_file.size
format = img_file.format
mode = img_file.mode

# Make image Greyscale
img_grey = img_file.convert('1')
img_grey.save('result.png')
img_grey.show()

# Save Greyscale values
value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
value = value.flatten()
value=[1 if x == 255 else x for x in value]
value.append(0)
with open("img_pixels.csv", 'a') as f:
  writer = csv.writer(f)
  writer.writerow(value)

# %%
path="/content/dataset/digit_0"
for j in os.listdir(path):
  img_file=Image.open(path+"/"+j)

  width, height = img_file.size
  format = img_file.format
  mode = img_file.mode

  # Make image Greyscale
  img_grey = img_file.convert('1')

  # Save Greyscale values
  value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
  value = value.flatten()
  value=[1 if x == 255 else x for x in value]
  value.append(0)
  with open("img_pixels.csv", 'a') as f:
    writer = csv.writer(f)
    writer.writerow(value)

# %%
# !cp "/content/img_pixels.csv" "/content/gdrive/My Drive/Urdu_mnist"
